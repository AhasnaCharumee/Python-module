# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
a = 1
b = 2
print(a+b)
# Out:
# 3

# %%
my_var = 5.0
print(my_var)
print(type(my_var))
# Out:
# 5.0
# <class 'float'>

# %%
newvariable8 = "Hello"
print(newvariable8)
# Out:
# Hello

# %%
a = 6.5e7
print(a)
print(type(a))
# Out:
# 65000000.0
# <class 'float'>

# %%
a = 5

b = float(a)
print(b)
print( type(b))
# Out:
# 5.0
# <class 'float'>

# %%
my_list = [1, 2, 3, 4]
print(my_list)
print(my_list[2])
print(type(my_list))
# Out:
# [1, 2, 3, 4]
# 3
# <class 'list'>

# %%
s = 4
print(id(s))
s = 9
print(id(s))
# Out:
# 140732400694280
# 140732400694440

# %%
print(id(my_list))
my_list[2] = 90
print(id(my_list))
# Out:
# 2104924957824
# 2104924957824

# %%
print(len(my_list))
# Out:
# 4

# %%
my_array = [1, 2.5, "Hello", [1, 2, 3]]
print(my_array)
print(type(my_array))
print(my_array[3])
# Out:
# [1, 2.5, 'Hello', [1, 2, 3]]
# <class 'list'>
# [1, 2, 3]

# %%
list_one = [1, 2, 3, 4, 5, 6, 7, 8, 9]
print(list_one[1:5:2])
# Out:
# [2, 4]

# %%
print(list_one[-4])
# Out:
# 6

# %%
my_list = [10,12,8,9,22,20,5,14]
my_list[2:5] = [100,200,300]
print(my_list)
# Out:
# [10, 12, 100, 200, 300, 20, 5, 14]

# %%
my_list = [10,12,8,9,22,20,5,14]
print(my_list)
my_list.clear()
print(my_list)
# Out:
# [10, 12, 8, 9, 22, 20, 5, 14]
# []

# %%
2+8
# Out:
# 10

# %%
my_list.insert(2, 50)
print(my_list)
my_list.append(90)
print(my_list)
my_list.remove(50)
# Out:
# [10, 12, 50, 50, 50, 50, 50, 100, 200, 300, 5, 14, 90, 90, 90, 90]
# [10, 12, 50, 50, 50, 50, 50, 100, 200, 300, 5, 14, 90, 90, 90, 90, 90]

# %%
del my_list 
print(my_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 del my_list
#       2 print(my_list)
#
# NameError: name 'my_list' is not defined

# %%
new_var = my_list.pop(7)
print(new_var)
print(my_list)
# Out:
# 90
# [10, 12, 50, 50, 50, 100, 14, 90, 90, 90, 90]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 5
#       3 print(my_list)
#       4 del my_list
# ----> 5 print(my_list)
#
# NameError: name 'my_list' is not defined
