# %%
# print(isinstance(x,int))
# This line checks if the variable x is of type integer and prints the result (True or False).
#type ekt aythid kiyl blnw

# %%
#number ekk integerd, floatd kiylblnne kohomd isinstance wlin
# print(isinstance(x, (float,int)))
# This line checks if the variable x is either of type float or integer and prints the result (True or False).

# %%
#python wl 3.6 idala string ekk variable  print kirim
# print(f"value of x is {x}")

# %%
#modules ynu thni file ekk
#module architecture is a way of structuring a program by breaking it down into smaller, manageable, and reusable components called modules.
#module athr intercommunication ekk pennnwa ek achieve krgnne

# %%
##remove  math. notaion and sankyawk wrgmuly print krnn



import math
input_value = int(input("Enter a number to find its factorial: "))
print(math.factorial(input_value))
# Out:
# 40320

# %%
##remove  math dot notation and sankyawk wargamulya print krnn
from math import sqrt,log2

number = 16
sqrt_value = sqrt(number)
print(f"The square  {number} is {sqrt_value}")


number2 = 8
log_value = log2(number2)
print(f"The log2  {number2} is {log_value}")
# Out:
# The square  16 is 4.0
# The log2  8 is 3.0

# %%
#from math import *  # imports all functions from the math module but is not good practice

# %%
#packages ynu module walin 
#packages ekk module walin wenas package ekk
#python interpreter , package ekk adurgnne init .py file ekk thiyenawanm
#init.py file hama package ekk athule thiyenawna 
#

# %%
#python class
#class name convention PascalCase

class Dog:

    name = "Buddy"  # Attribute to store the name of the dog
    age = 0    # Attribute to store the age of the dog

dog_1 = Dog()  # Creating an instance of the Dog class
print(dog_1.name)  # Accessing the name attribute of the dog_1 instance
# Out:
# Buddy

# %%
#write class player have class attribute score ptn gnnkotm 10 t set wenn on,write function in class addpoints .me function ekt eliyen parameter ekk enw score kiyl ekk. object ekk hdl function call kroth programm ek ptn gnn sore ekt ekthu unu ganth ekk final score ek print krnn on
class Player:
    score = 0  # Class attribute to store the player's score

    def add_points(self, points):
        self.score += points  # Method to add points to the player's score
# Create an instance of the Player class
player_1 = Player()
# Add 10 points to the player's score
player_1.add_points(10)
# Print the final score of the player
print(f"Final Score: {player_1.score}")
# Out:
# Final Score: 10

# %%
class Player:

    #class attribute
    score = 10
    #mandatory to use self in method wl
    #self is not a keyword in python but conventionally used

    #instance method
    def add_points( self,score):
       
       #pass krn variable wl scope ek loacal scope ekk wenwa
       #ek nisa local variables
       self.score += score
       
player_1 = Player()
player_1.add_points(10)
print(f"Final Score: {player_1.score}")

#self mean this in  java 
#self kiyl class eke instance ekk refer krnwa
#method wl attribute wlt self use krnne na 
#class athule liyn function key word wl plweni keyword ek self wenn ona
# Out:
# Final Score: 20

# %%
class Car:
    wheels = 4

    def drive_to(self, destination):
        print(f"Driving to {destination} on {self.wheels} wheels")

    def show_wheel_count(self):
        print(f"The car runs on {self.wheels} wheels")
car_1 = Car()
car_1.drive_to("500km")
car_1.show_wheel_count()
#write a python class name car that has a class attribute wheels set to 4 and two instance method drive_to which prints "driving to destination  > on < number of wheels >wheels and show_wheel_count" which print  "the car runs on <number of wheels>wheels"
# Out:
# Driving to 500km on 4 wheels
# The car runs on 4 wheels

# %%
#why we use constructor - class eken object ekk haduwm e class ekt adala attribute initialize krnn constructor ekk use krnwa
class Car:
    #class eken object ekk hdnkotm init call wenw 
    #class attribute eken hdn ham object ekkta adala attribute ekk
    wheels = 4

    #constructor method-instatnt attribute initialize krnn
    #best practice constructor method ek issellm liynw

    def __init__(self, brand, color, year):

    
# current object ekata adala attribute , instance attribute
    #object ekk haduwm e object ekt adala dewl thiyagnnn attribute ek

        self.brand = brand
        self.color = color #pitin apu parameter ekk


    def display_info(self):
        #get inputs 
        
        print(f"{self.color} {self.brand} has : {self.wheels} wheels")
#python wldi constructor overloading krnne na

# %%
import math
class Circle:


    def __init__(self, radius):
        self.radius = radius


    def area(self):
        return math.pi * (self.radius ** 2)

    def circumference(self):
        return 2 * math.pi * self.radius

    def display_info(self):
        area = self.area()
        circumference = self.circumference()
        print(f"Circle with radius {self.radius} has area {area} and circumference {circumference}.")

#instant method ekk athule thw instant method call krnn pullwn
circle_1 = Circle(14)
circle_1.display_info()
# Out:
# Circle with radius 14 has area 615.7521601035994 and circumference 87.96459430051421.

# %%
#inheritance

#super class
#base class
#parent class
class Animal:

    def __init__(self, name):
        self.name = name

    def speak(self):
        print(f"{self.name} makes an animal sound")

#Derrived class
#child class
#sub class
class Dog(Animal):

    pass

#create Dog object and call speak method
#sub classs doesnot  have constructor it inherit that from super class

dog_1 = Dog("Buddy")
dog_1.speak()  # Inherited method from Animal class

    

    #sub class ekt parent class eke attribute and methods inherit wenw
    #pass keyword eka use krnne empty class ekk hadnnm
# Out:
# Buddy makes an animal sound

# %%
class Animal:

    def __init__(self, name):
        self.name = name

    def speak(self):
        print(f"{self.name} makes an animal sound")

#Derrived class
#child class
#sub class
class Dog(Animal):
    def speak(self):
        print(f"{self.name} barks")
dog_1 = Dog("Buddy")
dog_1.speak()  # Calls the overridden method in Dog class
#thwdurtth valid wenne super class constructor ek
# Out:
# Buddy barks

# %%
class Animal:

    def __init__(self, name):
        self.name = name

    def speak(self):
        print(f"{self.name} makes an animal sound")




class Dog(Animal):
    def __init__(self, name,color):
        super().__init__(name)

        self.color = color
       
    def speak(self):
        print(f"{self.name} barks")

dog_1 = Dog("Buddy","Brown")
dog_1.speak()

print(f"{dog_1.name} is {dog_1.color}")
# Out:
# Buddy barks
# Buddy is Brown

# %%
#create a python class shape  with a name attribute and a method area that prints area calculation not defiened for <name> then create two sub classes squre and circle,that inherit from Shape . each sub class should : 1.have its all constructor to initialize appropriate attributes.overite the area method to calculate and print the area of the shape .use meaningful instance attribute for their calculation
class Shape:

    def __init__(self, name):
        self.name = name

    def area(self):
        print(f"Area calculation not defined for {self.name}")

class Square(Shape):

    def __init__(self, side_length):
        super().__init__("Square")
        self.side_length = side_length

    def area(self):
        area = self.side_length ** 2
        print(f"The area of the {self.name} is {area}")

class Circle(Shape):

    def __init__(self, radius):
        super().__init__("Circle")
        self.radius = radius

    def area(self):
        area = math.pi * (self.radius ** 2)
        print(f"The area of the {self.name} is {area}")

circle_1 = Circle(5)
circle_1.area()
square_1 = Square(4)
square_1.area()
# Out:
# The area of the Circle is 78.53981633974483
# The area of the Square is 16

# %%
class Car:
    wheel = 4

    def __init__(self, brand, color):
        self.brand = brand
        self.color = color

    def show_details(self):
        print(f"the {self.brand} car is {self.color} and has {self.wheel} wheels.")


my_car = Car("BMW", "Red")
my_car.show_details()
# Out:
# the BMW car is Red and has 4 wheels.
